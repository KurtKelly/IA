# %% [markdown]
# ### Tabla representativa para la optimiza
# | Modelo                 |      Hiperparámetros óptimos      |
# |------------------------|-----------------------------------|
# |           KNN          | n_neighbors=5, weights='distance' |
# |   Gaussian Naive Bayes |         var_smoothing=1           |
# |   Regresión Logística  |               C=1                 |
# |   Árbol de Decisión    |            max_depth=10           |
# |           SVM          | C=10, kernel='rbf', gamma='scale' |
# |      Random Forest     |   n_estimators=200, max_depth=2   |
